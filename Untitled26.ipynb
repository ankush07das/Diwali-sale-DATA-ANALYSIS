# %% [markdown]
# <a href="https://colab.research.google.com/github/ankush07das/FLIPKART-DATA-ANALYSIS/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# Try reading the file, handling bad lines and specifying the separator
df = pd.read_csv('/content/flipkart_com-ecommerce_sample.csv', on_bad_lines='warn', sep=',')

# If you still encounter issues, try exploring the file manually to identify the problematic lines
# and adjust the 'quoting' parameter if necessary.

# %%
df.head(5)
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df.isnull().sum()
# Out:
# uniq_id                       2
# crawl_timestamp               2
# product_url                   2
# product_name                  2
# product_category_tree         2
# pid                           2
# retail_price                 80
# discounted_price             80
# image                         5
# is_FK_Advantage_product       2
# description                   4
# product_rating                2
# overall_rating                2
# brand                      5866
# product_specifications       16
# dtype: int64

# %%
df['retail_price'].fillna(df['retail_price'].median(),inplace=True) # Call the median() method
df['discounted_price'].fillna(df['discounted_price'].median(),inplace=True) # Call the median() method

y=((df['retail_price']-df['discounted_price'])/(df['retail_price']))*100
df['discount_percentage']=y
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-20-d98a806de624> in <cell line: 1>()
# ----> 1 df['retail_price'].fillna(df['retail_price'].median(),inplace=True) # Call the median() method
#       2 df['discounted_price'].fillna(df['discounted_price'].median(),inplace=True) # Call the median() method
#       3
#       4 y=((df['retail_price']-df['discounted_price'])/(df['retail_price']))*100
#       5 df['discount_percentage']=y
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in median(self, axis, skipna, numeric_only, **kwargs)
#    6233         **kwargs,
#    6234     ):
# -> 6235         return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#    6236
#    6237     @doc(make_doc("sem", ndim=1))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
# ...

# %%
df.isnull().sum()
# Out:
# uniq_id                       2
# crawl_timestamp               2
# product_url                   2
# product_name                  2
# product_category_tree         2
# pid                           2
# retail_price                  0
# discounted_price              0
# image                         5
# is_FK_Advantage_product       2
# description                   4
# product_rating                2
# overall_rating                2
# brand                      5866
# product_specifications       16
# dtype: int64
